# %%
import importlib
import sys

# sys.path.append('home/elias/Genetic-Algorithms/energy optimization/') #Fix this

from pprint import pprint
import numpy as np
from deap import base, creator, tools
import random

import system.GA as GA
import system.GA2 as GA2
import system.GAplot as GAplot

import datalayer.getdata as getdata
import system.system_ as sys
import system.constraints as constraints

importlib.reload(sys)
importlib.reload(GA)
importlib.reload(getdata)
importlib.reload(constraints)



state = getdata.gen_state()
LOWER_BOUNDS, UPPER_BOUNDS, constraint = constraints.general_constraints(Glmax=max(state["load"]))

[Dmax, Glmax, Gbmax, Bmax, N_HOURS] = constraint

genome=96

# %%
fitness_history, D, Gl, Gb, g = GA2.simulation(100, 500, state, LOWER_BOUNDS, UPPER_BOUNDS, constraint)
# Out:
# /opt/miniconda3/envs/gaopt/lib/python3.12/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /opt/miniconda3/envs/gaopt/lib/python3.12/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Gen 0: Best = 68.58587385350913
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Gen 1: Best = 68.58587385350913
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Gen 2: Best = 68.58587385350913
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# Gen 3: Best = 68.58587385350913
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Gen 4: Best = 68.58587385350913
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Gen 5: Best = 68.58587385350913
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# ...
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# Gen 480: Best = 59.43854371156928
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Gen 481: Best = 59.43826679858313
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# Bounded error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# Gen 482: Best = 59.43756983377666
# Bounded error
# battery constraint error
# load constraint error
# Bounded error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# Gen 483: Best = 59.43720690811067
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Gen 484: Best = 59.43687149902406
# battery constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Gen 485: Best = 59.42926298829494
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# battery constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# Gen 486: Best = 59.42926298829494
# battery constraint error
# battery constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# battery constraint error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# battery constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# Gen 487: Best = 59.429024881534346
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# Gen 488: Best = 59.429024881534346
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# Bounded error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# Bounded error
# Bounded error
# Bounded error
# battery constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Gen 489: Best = 59.42814653916608
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# battery constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Gen 490: Best = 59.42802943582614
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Gen 491: Best = 59.42756454065589
# Bounded error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# battery constraint error
# Bounded error
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# Gen 492: Best = 59.42747838556031
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Gen 493: Best = 59.42742652542452
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# Bounded error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# battery constraint error
# Bounded error
# Bounded error
# load constraint error
# Bounded error
# Bounded error
# load constraint error
# Gen 494: Best = 59.42713900681724
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# Gen 495: Best = 59.42687076891238
# battery constraint error
# Bounded error
# Bounded error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# Bounded error
# battery constraint error
# Gen 496: Best = 59.42682905394939
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# Gen 497: Best = 59.42670036725052
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# Bounded error
# Bounded error
# Bounded error
# Gen 498: Best = 59.42541172669915
# Bounded error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# battery constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# Bounded error
# load constraint error
# load constraint error
# load constraint error
# battery constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# load constraint error
# Gen 499: Best = 59.42255296017812

# %%
importlib.reload(GAplot)
GAplot.plot_individual(D, Gl, Gb, g, state)
GAplot.plot_battery(D,Gb,g, state)
GAplot.plot_fitness(fitness_history)

# %%
# 58000 EUR? resonable?
# 60Kw * 24h * 40/1000 EUR/KWh 

print(60*24*40/1000)
# Out:
# 57.6
